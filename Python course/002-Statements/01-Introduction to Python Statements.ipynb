# %% [markdown]
# ## ========================================================================
# ## Introduction to Python Statements
# ### Mahdi Shafiee Kamalabad
# ## ========================================================================

# %% [markdown]
# ![If-Statement-in-Python.png](attachment:If-Statement-in-Python.png)

# %% [markdown]
# Let's create a simple statement that says:
#
# "If **a** is greater than **b**, assign **5** to **a** and **6** to **b**"
#
#
#     if a>b:
#         a = 5
#         b = 6

# %% [markdown]
# #### Note: Python is so heavily driven by code **indentation** and **whitespace**. This means that code **readability** is a core part of the design of the Python language.
#
# Now let's start diving deeper by coding these sort of statements in Python!
