# %% [markdown]
# ## ========================================================================
# ## List Comprehensions
# ### Mahdi Shafiee Kamalabad
# ## ========================================================================
#
# * It is essentially a one line <code>for</code> loop built inside of brackets.
#
# ![comprehension.PNG](attachment:comprehension.PNG)

# %% [markdown]
# ![list-comprehension-1-2.png](attachment:list-comprehension-1-2.png)

# %% [markdown]
# ## Example 1

# %%
# Grab every letter in string
lst = [x for x in 'word']

# %%
# Check
lst

# %% [markdown]
# This is the basic idea of a list comprehension.
#
# More examples of list comprehensions:
# ## Example 2

# %%
# Square numbers in range and turn into list
lst = [x**2 for x in range(0,11)]

# %%
lst

# %% [markdown]
# ## Example 3
# Let's see how to add in <code>if</code> statements:

# %%
# Check for even numbers in a range
lst = [x for x in range(11) if x % 2 != 0]

# %%
lst

# %% [markdown]
# ## Example 4
# Can also do more complicated arithmetic:

# %%
# Convert Celsius to Fahrenheit
celsius = [0,10,20.1,34.5]

fahrenheit = [((9/5)*temp + 32) for temp in celsius ]

fahrenheit

# %% [markdown]
# <br>

# %% [markdown]
# Easy or difficult?
# If interested, check the link below for more examples:
# https://docs.python.org/3/tutorial/datastructures.html#list-comprehensions
