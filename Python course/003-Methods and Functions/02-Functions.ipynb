# %% [markdown]
# ## ========================================================================
# ## Functions
# ### Mahdi Shafiee Kamalabad
# ## ========================================================================
#
#
# ## Introduction to Functions
#
# #### Functions
#
# * are one of the **main building blocks** when we construct larger amounts of code to solve problems.
# * are  useful devices that **group a set of statements** (they can be run more than once).
# * can also let us **specify parameters** that can serve as inputs to the functions.
# * allow us to **not have to repeatedly write the same code** again and again. E.g. we used a function **len()** to get the length of a string. Since checking the length of a sequence is a common task you would want to write a function that can do this repeatedly at command.
# * will also allow us to **start thinking of program design**.

# %% [markdown]
# ![pyfunc.png](attachment:pyfunc.png)

# %% [markdown]
# ## Function Topics
# * `def` keyword
# * simple example of a function
# * calling a function with `()`
# * accepting parameters
# * `print` versus `return`
# * adding in logic inside a function
# * adding in loops inside a function
# * tuple unpacking
# * interactions between functions

# %% [markdown]
# ![Python-Function-Syntax.png](attachment:Python-Function-Syntax.png)

# %% [markdown]
#  ----
#  ### Example:
# ![python-functions.png](attachment:python-functions.png)

# %%
#write the above-mentioned program here

# %% [markdown]
# ### def keyword
#
# A function's syntax in Python has the following form:

# %%
def name_of_function(arg1,arg2):
    '''
    This is where the function's Document String (docstring) goes.
    When you call help() on your function it will be printed out.
    '''
    # Put your code here
    # Return desired result

# %% [markdown]
# * We begin with <code>def</code> then a **space** followed by the name of the function.
# * Try to keep names relevant, for example len() is a good name for a length function.
# * you shouldn't call a function the same name as a [built-in function in Python](https://docs.python.org/3/library/functions.html) (such as len).
#
# * Next come a pair of parentheses with a number of arguments separated by a comma.
# * These **arguments are the inputs** for your function. You'll be able to use these inputs in your function and reference them.
# * After this you put a **colon**.
#
# * You must **indent** to begin the code inside your function correctly. Python makes use of *whitespace* to organize code. Lots of other programing languages do not do this.
#
# * The **docstring** is where you write a basic description of the function.
# * Using **Jupyter Notebooks**, you'll be able to read these **docstrings** by pressing **Shift+Tab** after a function name.
# * Docstrings are not necessary for simple functions, but it's good practice to put them in, so you or other people can easily understand the code you write.
#
#
# The best way to learn functions is by going through examples.

# %% [markdown]
# ### Simple example of a function

# %%
def say_hello():
    print('hello')

# %%
say_hello() # Shift+Tab , so there is no docstring

# %% [markdown]
# ### Calling a function with ()

# %% [markdown]
# Call the function:

# %%
say_hello()

# %% [markdown]
# If you forget the parenthesis (), it will simply display the fact that *say_hello* is a function.

# %%
say_hello

# %% [markdown]
# ### Accepting parameters (arguments)
# Let's write a function that greets people with their name.

# %%
# input is name here:
def greeting(name):
    print(f'Hello {name}')   # here we used print

# %%
greeting('Mahdi')

# %%
# absolute value ===> 4--> 4 and -4-->4
def absolute_value(num):
    """This function returns the absolute
    value of the entered number"""
    num = abs(num)
    return num

# absolute_value(2)

absolute_value(4)

# %%
# example for 5*x
def times_5(x):
    ''' 5*x
    '''
    y = 5*x
    return y

times_5()

# %%
# write a function for adding three number here
# multiply two numbers

def add_two_number(a,b):
    x= a+b
    return x

add_two_number(2,-4)

# %% [markdown]
# # Using return
# If we actually want to save the resulting variable we need to use the **return** keyword.
#
# **<code>return</code> allows a function to *return* a result that can then be stored as a variable, or used in whatever manner a user wants.**
#
# ### Example:

# %%
def add_num(num1,num2):
    return num1+num2

# %%
adding = add_num(4,5)

# %%
adding

# %%
# Can also save as variable due to return
result = add_num(4,5)

# %%
result

# %%
## write the previous program with print(), asign it to "result", result = add_num(4,5) and
## run it.

# %% [markdown]
# ### Create a Function that Returns Multiple Values in Python
#
# * To return multiple values from a function, just specify the values to be returned, separated by a comma.
# * By **default**, the function returns the values as **a tuple**. If there are N return values, we get an N-tuple.

# %%
# Let's create a simple function `cube()` that returns the **volume and total surface area** of a cube, 
# given the length of its side.

def cube(side):
    volume = side**3
    surface_area = (side**2)*6
    
    return volume, surface_area      # THIS MAKS PYTHON EASY TO USE.

# %%
returned_values = cube(8)
returned_values

# %% [markdown]
# #### Another example

# %%
# example: wite a program that return a given number +3

# %%
def add_three():
    """Return 3 + the number entered by the user."""
    number = int(input('Enter a number: '))
    return number + 3
add_three()

# %%
type(input())

# %% [markdown]
# ### Adding Logic to Internal Function Operations
#
# So far we know  a bit about constructing logical statements with Python, such as `if/else/elif` statements, `for` and `while` loops, checking if an item is **`in`** a list or **`not in`** a list (Useful Operators Lecture). Now see how we can perform these operations within a function.

# %% [markdown]
# ### Check if a number is even

# %% [markdown]
# **Recall the mod operator % which returns the remainder after division, if a number is even then mod 2 (% 2) should be == to zero.**

# %%
20 % 2 == 0

# %%
21 % 2 == 0

# %% [markdown]
# **Let's use this to construct a function. Notice how we simply return the boolean check.**

# %%
# example, write a program that returns whether a number is even. That is return number % 2 == 0
def even_check(num):
    if num%2==0:
        out= print(f'{num} is even')
    else:
        out=print("not even")
        
    return out

# %%
even_check(20)

# %%
even_check(21)

# %% [markdown]
# ### Check if any number in  a list is even
#
# Let's return a boolean indicating if **any** number in a list is even. Notice here how **return** breaks out of the loop and exits the function.

# %% [markdown]
# **Correct approach: We need to initiate a "return False" AFTER running through the entire loop**.

# %%
def check_even_list(num_list):
    # Go through each number
    for number in num_list:
        # Once we get a "hit" on an even number, we return True
        if number % 2 == 0:
            return True
        # Don't do anything if its not even just  pass here
        else:
            pass # do nothing
    # Notice the indentation! This ensures we run through the entire for loop    
    return False

# %%
check_even_list([1,2,3])

# %%
check_even_list([1,3,5])

# %%
# a program to sum up a list

# %% [markdown]
# ##  BOUNS: Interactions between functions
#
# Functions often use results from other functions, let's see a simple example through a guessing game. There will be 3 positions in the list, one of which is an 'O', a function will shuffle the list, another will take a player's guess, and finally another will check to see if it is correct. This is based on the classic carnival game of guessing which cup a red ball is under.

# %% [markdown]
# **How to shuffle a list in Python**

# %%
example = [1,2,3,4,5]

# %%
from random import shuffle

# %%
# Note shuffle is in-place
shuffle(example)

# %%
example

# %% [markdown]
# OK, let's create our simple game.

# %%
mylist = [' ','O',' ']

# %%
def shuffle_list(mylist):
    # Take in list, and returned shuffle versioned
    shuffle(mylist)
    
    return mylist

# %%
mylist

# %%
shuffle_list(mylist)

# %%
def player_guess():
    
    guess = ''
    
    while guess not in ['0','1','2']:
        
        # Recall input() returns a string
        guess = input("Pick a number: 0, 1, or 2:  ")
    
    return int(guess)

# %%
player_guess()

# %% [markdown]
# Now we will check the user's guess. Notice we only print here, since we have no need to save a user's guess or the shuffled list.

# %%
def check_guess(mylist,guess):
    if mylist[guess] == 'O':
        print('Correct Guess!')
    else:
        print('Wrong! Better luck next time')
        print(mylist)

# %% [markdown]
# Now we create a little setup logic to run all the functions. Notice how they interact with each other!

# %%
# Initial List
mylist = [' ','O',' ']

# Shuffle It
mixedup_list = shuffle_list(mylist)

# Get User's Guess
guess = player_guess()

# Check User's Guess
#------------------------
# Notice how this function takes in the input 
# based on the output of other functions!
check_guess(mixedup_list,guess)
